# %% [markdown]
# ### 판다스 시각화
# **- https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html**

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline 
# 주피터 노트북 상에서 그래프를 보이게 한다

# 한글폰트 사용시 그래프에서 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame()

# %% [markdown]
# ## Plot
# ### kind : str
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2000',periods=1000))

# %%
ts
# Out:
# 2000-01-01    0.309809
# 2000-01-02    0.201150
# 2000-01-03    0.445229
# 2000-01-04    0.830330
# 2000-01-05    0.780555
#                 ...
# 2002-09-22    0.576962
# 2002-09-23    0.421941
# 2002-09-24    1.703402
# 2002-09-25   -0.526410
# 2002-09-26   -0.835912
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))

# %%
df #시계열 데이터 생성
# Out:
#                    A         B         C         D
# 2000-01-01  0.644926  1.650453  0.805540  0.644288
# 2000-01-02 -0.111300 -0.404783 -1.457050  0.332342
# 2000-01-03 -0.183369 -0.186235 -0.418154 -0.891766
# 2000-01-04 -0.009355 -0.349730  0.892962 -1.665478
# 2000-01-05  0.143996 -0.247507 -0.105773  0.840040
# ...              ...       ...       ...       ...
# 2002-09-22 -0.718924 -0.386848  2.191252 -0.532686
# 2002-09-23 -1.357681 -1.721050 -1.555816  0.159706
# 2002-09-24  0.301294  0.519050  0.445811  0.533130
# 2002-09-25  0.707107  0.089733  0.890149  0.204437
# 2002-09-26 -1.199675  0.595369 -0.224843  0.846575
#
# [1000 rows x 4 columns]

# %%
df.plot()

# %%
df = df.cumsum()

# %%
df.plot()

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df
# Out:
#                     A          B          C         D
# 2000-01-01   0.644926   1.650453   0.805540  0.644288
# 2000-01-02   0.533625   1.245669  -0.651510  0.976630
# 2000-01-03   0.350257   1.059434  -1.069664  0.084864
# 2000-01-04   0.340902   0.709704  -0.176702 -1.580615
# 2000-01-05   0.484898   0.462197  -0.282475 -0.740575
# ...               ...        ...        ...       ...
# 2002-09-22 -27.644797  30.955932 -25.146684  0.185610
# 2002-09-23 -29.002478  29.234882 -26.702500  0.345316
# 2002-09-24 -28.701184  29.753932 -26.256689  0.878446
# 2002-09-25 -27.994078  29.843665 -25.366540  1.082883
# 2002-09-26 -29.193753  30.439034 -25.591383  1.929458
#
# [1000 rows x 4 columns]

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.head()
# Out:
#           B         C  A
# 0 -0.011744  1.107882  0
# 1  0.111290  0.757702  1
# 2  0.289470  0.287332  2
# 3 -0.480550  0.979338  3
# 4 -1.380551 -0.682610  4

# %%
df3.plot(x='A', y='B') # x축에는 A, y축에는 B 값을 넣어줬다
